# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9dd3e54f4610> in <module>
# ----> 1 X<-data.frame(c(1,2,3),c(1,2,3))
#       2 names(X)<-c("x1","x2")
#       3
#
# NameError: name 'X' is not defined
